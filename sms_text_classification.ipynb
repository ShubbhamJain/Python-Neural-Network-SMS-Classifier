# %% [markdown]
# In this project we have created a machine learning model that will classify SMS messages as either "ham" or "spam". A "ham" message is a normal message sent by a friend. A "spam" message is an advertisement or a message sent by a company.
#
# We have created a function called `predict_message` that takes a message string as an argument and returns a list. The first element in the list is a number between zero and one that indicates the likeliness of "ham" (0) or "spam" (1). The second element in the list is the word "ham" or "spam", depending on which is most likely.
#
# For this project, we are using the [SMS Spam Collection dataset](http://www.dt.fee.unicamp.br/~tiago/smsspamcollection/). The dataset has already been grouped into train data and test data.
#
# The first two cells import the libraries and data. The final cell tests the model.

# %%
# import libraries
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Embedding, Dense
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (4.0.1)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (21.4.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (0.16.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (0.1.7)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (3.17.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (2.23.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (5.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (1.21.6)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (1.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (1.15.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (1.8.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (4.64.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (1.1.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets) (0.3.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow-datasets) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2.10)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources->tensorflow-datasets) (3.8.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-metadata->tensorflow-datasets) (1.56.1)

# %%
# get data files
# !wget https://cdn.freecodecamp.org/project-data/sms/train-data.tsv
# !wget https://cdn.freecodecamp.org/project-data/sms/valid-data.tsv

train_file_path = "train-data.tsv"
test_file_path = "valid-data.tsv"
# Out:
# --2022-05-24 20:16:50--  https://cdn.freecodecamp.org/project-data/sms/train-data.tsv
# Resolving cdn.freecodecamp.org (cdn.freecodecamp.org)... 104.26.2.33, 172.67.70.149, 104.26.3.33, ...
# Connecting to cdn.freecodecamp.org (cdn.freecodecamp.org)|104.26.2.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 358233 (350K) [text/tab-separated-values]
# Saving to: ‘train-data.tsv.5’
#
# train-data.tsv.5    100%[===================>] 349.84K  --.-KB/s    in 0.03s
#
# 2022-05-24 20:16:50 (11.0 MB/s) - ‘train-data.tsv.5’ saved [358233/358233]
#
# --2022-05-24 20:16:50--  https://cdn.freecodecamp.org/project-data/sms/valid-data.tsv
# Resolving cdn.freecodecamp.org (cdn.freecodecamp.org)... 104.26.2.33, 172.67.70.149, 104.26.3.33, ...
# Connecting to cdn.freecodecamp.org (cdn.freecodecamp.org)|104.26.2.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 118774 (116K) [text/tab-separated-values]
# Saving to: ‘valid-data.tsv.5’
#
# valid-data.tsv.5    100%[===================>] 115.99K  --.-KB/s    in 0.01s
#
# 2022-05-24 20:16:51 (9.83 MB/s) - ‘valid-data.tsv.5’ saved [118774/118774]

# %%
names = ["class", "message"]
train_file = pd.read_csv(train_file_path, sep='\t', names=names)
train_file
# Out:
#      class                                            message
# 0      ham  ahhhh...just woken up!had a bad dream about u ...
# 1      ham                           you can never do nothing
# 2      ham  now u sound like manky scouse boy steve,like! ...
# 3      ham  mum say we wan to go then go... then she can s...
# 4      ham  never y lei... i v lazy... got wat? dat day ü ...
# ...    ...                                                ...
# 4174   ham  just woke up. yeesh its late. but i didn't fal...
# 4175   ham  what do u reckon as need 2 arrange transport i...
# 4176  spam  free entry into our £250 weekly competition ju...
# 4177  spam  -pls stop bootydelious (32/f) is inviting you ...
# 4178   ham  tell my  bad character which u dnt lik in me. ...
#
# [4179 rows x 2 columns]

# %%
test_file = pd.read_csv(test_file_path, sep='\t', names=names)
test_file
# Out:
#      class                                            message
# 0      ham  i am in hospital da. . i will return home in e...
# 1      ham         not much, just some textin'. how bout you?
# 2      ham  i probably won't eat at all today. i think i'm...
# 3      ham  don‘t give a flying monkeys wot they think and...
# 4      ham                                who are you seeing?
# ...    ...                                                ...
# 1387   ham  true dear..i sat to pray evening and felt so.s...
# 1388   ham               what will we do in the shower, baby?
# 1389   ham  where are you ? what are you doing ? are yuou ...
# 1390  spam  ur cash-balance is currently 500 pounds - to m...
# 1391  spam  not heard from u4 a while. call 4 rude chat pr...
#
# [1392 rows x 2 columns]

# %%
train_message = train_file["message"].values.tolist()
train_label = np.array([0 if x=="ham" else 1 for x in train_file['class'].values.tolist()])
test_message = test_file["message"].values.tolist()
test_label = np.array([0 if x=="ham" else 1 for x in test_file['class'].values.tolist()])

# %%
vocabulary_dict = {}
for messgae in train_message:
  for vocabulary in messgae.split():
    if vocabulary not in vocabulary_dict:
      vocabulary_dict[vocabulary] = 1
    else:
      vocabulary_dict[vocabulary] += 1

# %%
VOCAB_SIZE = len(vocabulary_dict)
MAX_LENGTH = len(max(train_message, key=lambda p: len(p.split())).split())

# %%
encoded_train_message = [one_hot(d, VOCAB_SIZE) for d in train_message]
padded_train_message = pad_sequences(encoded_train_message, maxlen=MAX_LENGTH, padding='post')
encoded_test_message = [one_hot(d, VOCAB_SIZE) for d in test_message]
padded_test_message = pad_sequences(encoded_test_message, maxlen=MAX_LENGTH, padding='post')

# %%
model = Sequential()
embedding_layer = Embedding(VOCAB_SIZE, 100, input_length=MAX_LENGTH)
model.add(embedding_layer)
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
monitor = EarlyStopping(monitor='val_acc', min_delta=1e-4, patience=25, verbose=1, mode='max', restore_best_weights=True)
model.fit(padded_train_message, train_label, validation_data=(padded_test_message, test_label), callbacks=[monitor], epochs=1000, verbose=2)
# Out:
# Epoch 1/1000
# 131/131 - 1s - loss: 0.2372 - acc: 0.9151 - val_loss: 0.0926 - val_acc: 0.9741 - 1s/epoch - 10ms/step
# Epoch 2/1000
# 131/131 - 1s - loss: 0.0538 - acc: 0.9849 - val_loss: 0.0544 - val_acc: 0.9835 - 577ms/epoch - 4ms/step
# Epoch 3/1000
# 131/131 - 1s - loss: 0.0264 - acc: 0.9933 - val_loss: 0.0435 - val_acc: 0.9871 - 578ms/epoch - 4ms/step
# Epoch 4/1000
# 131/131 - 1s - loss: 0.0140 - acc: 0.9962 - val_loss: 0.0395 - val_acc: 0.9856 - 582ms/epoch - 4ms/step
# Epoch 5/1000
# 131/131 - 1s - loss: 0.0083 - acc: 0.9990 - val_loss: 0.0371 - val_acc: 0.9878 - 502ms/epoch - 4ms/step
# Epoch 6/1000
# 131/131 - 1s - loss: 0.0055 - acc: 0.9995 - val_loss: 0.0399 - val_acc: 0.9878 - 564ms/epoch - 4ms/step
# Epoch 7/1000
# 131/131 - 1s - loss: 0.0040 - acc: 0.9998 - val_loss: 0.0409 - val_acc: 0.9878 - 765ms/epoch - 6ms/step
# Epoch 8/1000
# 131/131 - 1s - loss: 0.0031 - acc: 0.9998 - val_loss: 0.0415 - val_acc: 0.9878 - 797ms/epoch - 6ms/step
# Epoch 9/1000
# 131/131 - 1s - loss: 0.0027 - acc: 0.9998 - val_loss: 0.0398 - val_acc: 0.9878 - 805ms/epoch - 6ms/step
# Epoch 10/1000
# 131/131 - 1s - loss: 0.0023 - acc: 0.9998 - val_loss: 0.0391 - val_acc: 0.9885 - 955ms/epoch - 7ms/step
# Epoch 11/1000
# 131/131 - 1s - loss: 0.0019 - acc: 0.9998 - val_loss: 0.0355 - val_acc: 0.9899 - 780ms/epoch - 6ms/step
# Epoch 12/1000
# 131/131 - 1s - loss: 0.0017 - acc: 0.9998 - val_loss: 0.0380 - val_acc: 0.9892 - 835ms/epoch - 6ms/step
# Epoch 13/1000
# 131/131 - 1s - loss: 0.0013 - acc: 0.9998 - val_loss: 0.0423 - val_acc: 0.9885 - 843ms/epoch - 6ms/step
# Epoch 14/1000
# 131/131 - 1s - loss: 0.0010 - acc: 0.9998 - val_loss: 0.0409 - val_acc: 0.9885 - 826ms/epoch - 6ms/step
# Epoch 15/1000
# 131/131 - 1s - loss: 7.8212e-04 - acc: 0.9998 - val_loss: 0.0435 - val_acc: 0.9885 - 818ms/epoch - 6ms/step
# Epoch 16/1000
# 131/131 - 1s - loss: 6.2117e-04 - acc: 0.9998 - val_loss: 0.0436 - val_acc: 0.9885 - 834ms/epoch - 6ms/step
# Epoch 17/1000
# 131/131 - 1s - loss: 5.0579e-04 - acc: 0.9998 - val_loss: 0.0392 - val_acc: 0.9892 - 877ms/epoch - 7ms/step
# Epoch 18/1000
# 131/131 - 1s - loss: 3.8001e-04 - acc: 1.0000 - val_loss: 0.0446 - val_acc: 0.9885 - 964ms/epoch - 7ms/step
# Epoch 19/1000
# 131/131 - 1s - loss: 3.1925e-04 - acc: 1.0000 - val_loss: 0.0444 - val_acc: 0.9892 - 922ms/epoch - 7ms/step
# Epoch 20/1000
# 131/131 - 1s - loss: 2.5876e-04 - acc: 1.0000 - val_loss: 0.0454 - val_acc: 0.9885 - 842ms/epoch - 6ms/step
# Epoch 21/1000
# 131/131 - 1s - loss: 2.2338e-04 - acc: 1.0000 - val_loss: 0.0460 - val_acc: 0.9878 - 858ms/epoch - 7ms/step
# Epoch 22/1000
# 131/131 - 1s - loss: 1.9148e-04 - acc: 1.0000 - val_loss: 0.0464 - val_acc: 0.9878 - 876ms/epoch - 7ms/step
# Epoch 23/1000
# 131/131 - 1s - loss: 1.6371e-04 - acc: 1.0000 - val_loss: 0.0469 - val_acc: 0.9878 - 987ms/epoch - 8ms/step
# Epoch 24/1000
# 131/131 - 1s - loss: 1.3933e-04 - acc: 1.0000 - val_loss: 0.0483 - val_acc: 0.9878 - 621ms/epoch - 5ms/step
# Epoch 25/1000
# 131/131 - 0s - loss: 1.2609e-04 - acc: 1.0000 - val_loss: 0.0482 - val_acc: 0.9878 - 493ms/epoch - 4ms/step
# Epoch 26/1000
# 131/131 - 1s - loss: 1.1106e-04 - acc: 1.0000 - val_loss: 0.0478 - val_acc: 0.9878 - 559ms/epoch - 4ms/step
# Epoch 27/1000
# 131/131 - 0s - loss: 9.9982e-05 - acc: 1.0000 - val_loss: 0.0477 - val_acc: 0.9892 - 481ms/epoch - 4ms/step
# Epoch 28/1000
# 131/131 - 1s - loss: 8.7559e-05 - acc: 1.0000 - val_loss: 0.0482 - val_acc: 0.9885 - 542ms/epoch - 4ms/step
# Epoch 29/1000
# 131/131 - 0s - loss: 7.9074e-05 - acc: 1.0000 - val_loss: 0.0491 - val_acc: 0.9878 - 452ms/epoch - 3ms/step
# Epoch 30/1000
# 131/131 - 0s - loss: 7.1113e-05 - acc: 1.0000 - val_loss: 0.0501 - val_acc: 0.9878 - 471ms/epoch - 4ms/step
# Epoch 31/1000
# 131/131 - 1s - loss: 6.3112e-05 - acc: 1.0000 - val_loss: 0.0506 - val_acc: 0.9878 - 536ms/epoch - 4ms/step
# Epoch 32/1000
# 131/131 - 1s - loss: 5.7866e-05 - acc: 1.0000 - val_loss: 0.0513 - val_acc: 0.9878 - 545ms/epoch - 4ms/step
# Epoch 33/1000
# 131/131 - 0s - loss: 5.2456e-05 - acc: 1.0000 - val_loss: 0.0512 - val_acc: 0.9878 - 462ms/epoch - 4ms/step
# Epoch 34/1000
# 131/131 - 1s - loss: 4.6994e-05 - acc: 1.0000 - val_loss: 0.0523 - val_acc: 0.9878 - 536ms/epoch - 4ms/step
# Epoch 35/1000
# 131/131 - 0s - loss: 4.3264e-05 - acc: 1.0000 - val_loss: 0.0522 - val_acc: 0.9878 - 466ms/epoch - 4ms/step
# Epoch 36/1000
# Restoring model weights from the end of the best epoch: 11.
# 131/131 - 1s - loss: 3.9262e-05 - acc: 1.0000 - val_loss: 0.0522 - val_acc: 0.9878 - 522ms/epoch - 4ms/step
# Epoch 36: early stopping

# %%
# function to predict messages based on model
# (should return list containing prediction and label, ex. [0.008318834938108921, 'ham'])
def predict_message(pred_text):
  class_dict = {
      0 : "ham", 
      1 : "spam",   
      }
  encoded_message = [one_hot(pred_text, VOCAB_SIZE)]
  padded_message = pad_sequences(encoded_message, maxlen=MAX_LENGTH, padding='post')
  prediction = [model.predict(padded_message)[0][0], class_dict[np.round(model.predict(padded_message)[0][0])]]
  return prediction

pred_text = "how are you doing today?"

prediction = predict_message(pred_text)
print(prediction)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 19ms/step
# [0.0006516647, 'ham']

# %%
def test_predictions():
  test_messages = ["how are you doing today",
                   "i dont want to go. can we try it a different day? available sat",
                   "our new mobile video service is live. just install on your phone to start watching.",
                   "you have won £1000 cash! call to claim your prize.",
                   "i'll bring it tomorrow. don't forget the milk.",
                   "wow, is your arm alright. that happened to me one time too"
                  ]

  test_answers = ["ham", "ham", "spam", "spam", "ham", "ham"]
  passed = True

  for msg, ans in zip(test_messages, test_answers):
    prediction = predict_message(msg)
    print(prediction)
    if prediction[1] != ans:
      passed = False

  if passed:
    print("Model predicting correctly. Great job!")
  else:
    print("Model predicted incorrectly.")

test_predictions()
# Out:
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 46ms/step
# [0.0006516647, 'ham']
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# [1.8646322e-05, 'ham']
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# [0.9985318, 'spam']
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 30ms/step
# [0.99803, 'spam']
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 26ms/step
# [0.00019803592, 'ham']
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# [0.0026397163, 'ham']
# Model predicting correctly. Great job!
